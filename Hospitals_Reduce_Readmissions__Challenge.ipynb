# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Data Import
df = pd.read_csv('/content/diabetic_data.csv')
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
#Create Hospitals Readmissions Data
hospitals_readmissions = df[['age','time_in_hospital','num_procedures','num_lab_procedures','num_medications','number_outpatient','number_inpatient','number_emergency','medical_specialty','diag_1','diag_2','diag_3','max_glu_serum','A1Cresult','change','diabetesMed','readmitted']]
hospitals_readmissions.head()

hospitals_readmissions = hospitals_readmissions.rename(mapper={'age':'age','time_in_hospital':'time_in_hospital','num_procedures':'n_procedures','num_lab_procedures':'n_lab_procedures';'num_medications':'n_medications','number_outpatient':'n_outpatient','number_inpatient':'n_inpatient','number_emergency':'n_emergency','medical_specialty':'medical_specialty','diag_1':'diag_1','diag_2':'diag_2','diag_3':'diag_3','max_glu_serum':'glucose_test','A1Cresult':'A1Ctest','change':'change','diabetesMed':'diabetes_med','readmitted':'readmitted'}, axis=1)
hospitals_readmissions['column name'] = df['column name'].replace(['old value'], 'new value')
# Out:
#   File "<ipython-input-19-b2622a9c5843>", line 5
#     hospitals_readmissions = hospitals_readmissions.rename(mapper={'age':'age','time_in_hospital':'time_in_hospital','num_procedures':'n_procedures','num_lab_procedures':'n_lab_procedures';'num_medications':'n_medications','number_outpatient':'n_outpatient','number_inpatient':'n_inpatient','number_emergency':'n_emergency','medical_specialty':'medical_specialty','diag_1':'diag_1','diag_2':'diag_2','diag_3':'diag_3','max_glu_serum':'glucose_test','A1Cresult':'A1Ctest','change':'change','diabetesMed':'diabetes_med','readmitted':'readmitted'}, axis=1)
#                                                                                                                                                                                             ^
# SyntaxError: invalid syntax
